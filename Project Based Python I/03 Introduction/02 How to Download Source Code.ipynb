# %% [markdown]
# <img src="./images/banner-download-source-code.png" width="800">

# %% [markdown]
# ## Method 1: Using Git
#
# ### Step 1: Install Git (if not already installed)
#
# 1. **Mac:**
#    - Open Terminal.
#    - Check if Git is installed: `git --version`
#    - If not installed, you'll be prompted to install the Xcode Command Line Tools.
#
# 2. **Linux:**
#    - Open Terminal.
#    - Check if Git is installed: `git --version`
#    - If not installed, use your package manager to install Git. For example, on Debian-based systems: `sudo apt-get install git`
#
# 3. **WSL:**
#    - Open your WSL terminal.
#    - Check if Git is installed: `git --version`
#    - If not installed, use your Linux package manager to install Git.
#
# ### Step 2: Clone the Repository
#
# 1. **Open Terminal (Mac and Linux) or Command Prompt (WSL):**
#
# 2. **Navigate to Desired Directory:**
#
# 3. **Clone the Repository:**
#
# ### Step 3: Update the Repository
#
# 1. **Navigate to Repository Directory:**
#
# 2. **Pull Changes:**
#
# ## Method 2: Using the Download Button
#
# ### Step 1: Download the Repository ZIP
#
# 1. **Open Your Web Browser:**
#
# 2. **Click on "Code" Button:**
#
# 3. **Click "Download ZIP":**
#
# ### Step 2: Extract the ZIP
#
# 1. **Navigate to Downloads:**
#
# 2. **Extract ZIP:**
#
# ### Refreshing Files:
#
# If you want to refresh the files using the Download button method, you can follow these steps:
#
# 1. **Download ZIP Again:** Repeat the steps in "Step 1: Download the Repository ZIP" to download the ZIP file again.
#
# 2. **Extract ZIP:** Repeat the steps in "Step 2: Extract the ZIP" to extract the newly downloaded ZIP file.
#
# By downloading and extracting the ZIP file again, you'll get the latest version of the repository's contents.
#
# ## Platform-Specific Instructions
#
# ### Mac:
#
# - **Terminal Access:** Applications > Utilities > Terminal
#
# ### Linux:
#
# - **Terminal Access:** You can usually find the terminal by searching in your application menu or pressing `Ctrl` + `Alt` + `T`.
#
# ### Windows Subsystem for Linux (WSL):
#
# 1. **Enable WSL:** If you haven't already, you need to enable and install WSL on your Windows system. Follow official Microsoft documentation to do this.
#
# 2. **Access WSL:** You can open the WSL terminal by searching for "WSL" in the Windows search bar or by running `wsl` in the Command Prompt.
#
# 3. **Navigate to Windows Drives:** In WSL, you can access your Windows drives under the `/mnt` directory. For example, your C: drive will be under `/mnt/c/`.
#
# Remember to consult official documentation for any updates or changes that might have occurred after my last update in September 2021.
